# %% [markdown]
# # OOP Assignment (Based on Your Class)
#
# This assignment is based on the topics covered in your class: Class, Object, Attributes, Methods, Constructor (`__init__`), Class Attribute, Instance Attribute and Inheritance.

# %% [markdown]
# ## Question 1
#
# Create an `Animal` class with attribute `name='Lion'` and method `speak()`. Create an object and access both.
#
# **Sample Input**
# ```
# Use suitable values
# ```
#
# **Expected Output**
# ```
# Display the required details correctly.
# ```

# %%
# Write your code here

class Animal:
    name='Lion'

    def speak(self):
        print("lion roars")
obj=Animal()
print(obj.name)
obj.speak()
# Out:
# Lion
# lion roars

# %% [markdown]
# ## Question 2
#
# Create a `Student` class using constructor to store name, age and course. Create two objects and display details.
#
# **Sample Input**
# ```
# Use suitable values
# ```
#
# **Expected Output**
# ```
# Display the required details correctly.
# ```

# %%
# Write your code here
class Student:
    def __init__(self,name,age,course):
        self.name=name
        self.age=age
        self.course=course

    def details(self):
        print("Name:",self.name) 
        print("Age:",self.age)
        print("Course:",self.course)

obj=Student("Archana",20,"DS")
obj2=Student("Varun",17,"web dev")
obj.details()   
obj2.details()
# Out:
# Name: Archana
# Age: 20
# Course: DS
# Name: Varun
# Age: 17
# Course: web dev

# %% [markdown]
# ## Question 3
#
# Create a `BagFactory` class with constructor accepting material, zips and pockets. Create two bag objects and print details.
#
# **Sample Input**
# ```
# Use suitable values
# ```
#
# **Expected Output**
# ```
# Display the required details correctly.
# ```

# %%
# Write your code here
class Bagfactory:
    def __init__(self,material,zips,pockets):
        self.material=material
        self.zips=zips
        self.pockets=pockets

    def details(self):
        print("Material:",self.material) 
        print("Zips:",self.zips)
        print("Pockets:",self.pockets)

campus=Student("leather",5,4)
reebok=Student("ployester",7,5)
campus.details()   
reebok.details()
# Out:
# Name: leather
# Age: 5
# Course: 4
# Name: ployester
# Age: 7
# Course: 5

# %% [markdown]
# ## Question 4
#
# Create a `Car` class with company, model and price. Display details using a method.
#
# **Sample Input**
# ```
# Use suitable values
# ```
#
# **Expected Output**
# ```
# Display the required details correctly.
# ```

# %%
# Write your code here
class Car:
    def __init__(self,company,model,price):
        self.company=company
        self.model=model
        self.price=price

    def details(self):
        print("Comapany:",self.company)
        print("Model:",self.model)
        print("price:",self.price)

Tata=Car("Tata","Nexon",1000000)  
Suzuki=Car("Suzuki","Swift",1200000)

Tata.details()
Suzuki.details()
# Out:
# Comapany: Tata
# Model: Nexon
# price: 1000000
# Comapany: Suzuki
# Model: Swift
# price: 1200000

# %% [markdown]
# ## Question 5
#
# Create an `Employee` class. Take input from the user using constructor and display details.
#
# **Sample Input**
# ```
# Use suitable values
# ```
#
# **Expected Output**
# ```
# Display the required details correctly.
# ```

# %%
# Write your code here
class Employee:
    def __init__(self,emp_id,name,salary):
        self.emp_id=emp_id
        self.name=name
        self.salary=salary

    def details(self):
        print("Emp Id:",self.emp_id)
        print("Name:",self.name)
        print("Salary:",self.salary)  
emp_id=input("emp_id:")
name=input("Name:")
salary=int(input("Salary:"))          
obj=Employee(emp_id,name,salary)
obj.details()
# Out:
# Emp Id: 101
# Name: archu
# Salary: 2000000

# %% [markdown]
# ## Question 6
#
# Create a `Registration` class having class attribute `school_name`. Store student details using object attributes and display all information.
#
# **Sample Input**
# ```
# Use suitable values
# ```
#
# **Expected Output**
# ```
# Display the required details correctly.
# ```

# %%
# Write your code here
class Registration:
    
    school_name = "LNCT University"

    def __init__(self, name, age, course):
    
        self.name = name
        self.age = age
        self.course = course

    def display(self):
        print("School Name:", Registration.school_name)
        print("Student Name:", self.name)
        print("Age:", self.age)
        print("Course:", self.course)



obj1 = Registration("Archana", 20, "B.Tech CSE AIML")
obj2 = Registration("Rahul", 21, "B.Tech CSE")


print("Student 1 Details")
obj1.display()

print("\nStudent 2 Details")
obj2.display()
# Out:
# Student 1 Details
# School Name: LNCT University
# Student Name: Archana
# Age: 20
# Course: B.Tech CSE AIML
#
# Student 2 Details
# School Name: LNCT University
# Student Name: Rahul
# Age: 21
# Course: B.Tech CSE

# %% [markdown]
# ## Question 7
#
# Create a `StudentRegistration` class. Register students only if age is 20 or below; otherwise print 'Registration Failed'.
#
# **Sample Input**
# ```
# Use suitable values
# ```
#
# **Expected Output**
# ```
# Display the required details correctly.
# ```

# %%
# Write your code here
class StudentRegistration:
    def __init__(self,name,age):
        self.name=name
        self.age=age

        if self.age>20:
            print("Registration failed.")
        else:
            print("Registration successful.")    
    def showdetails(self):
        print(f"Your details are:\n")
        print(f"Name:{self.name}")
        print(f"Age:{self.age}")
Student1=StudentRegistration("archana",20)
Student1.showdetails()
# Out:
# Registration failed.
# Your details are:
#
# Name:archana
# Age:22

# %% [markdown]
# ## Question 8
#
# Modify Q7 by keeping count of successfully registered students using a class attribute.
#
# **Sample Input**
# ```
# Use suitable values
# ```
#
# **Expected Output**
# ```
# Display the required details correctly.
# ```

# %%
# Write your code here
class StudentRegister:
    student_count=0
    def __init__(self,name,age,student_class):
        
        self.name=name
        self.age=age
        self.cls=student_class
        self.registered=False
        if self.age>20:
            print(f"Registration failed:{name} is not eligible to register (age is above 20)")
        else:
            self.registered=True
            StudentRegister.student_count+=1
            print(f"Registration successful:{self.name}")    
        
    def Showdetails(self):
        if self.registered:
            print(f"Total students are:{self.student_count}")
            print(f"Your details are: \n")
            print(f"Name:{self.name}")
            print(f"Age:{self.age}")
            print(f"Class:{self.cls}")
student1=StudentRegister('Archana',19,10)
student2=StudentRegister('Varun',21,10)
student3=StudentRegister('Meera',18,12)        

student3.Showdetails()
# Out:
# Registration successful:Archana
# Registration failed:Varunis not eligible to register (age is above 20)
# Registration successful:Meera
# Total students are:2
# Your details are:
#
# Name:Meera
# Age:18
# Class:12

# %% [markdown]
# ## Question 9
#
# Create a parent class `Animal` with method `speak()`. Create child class `Dog` using inheritance and access the inherited method.
#
# **Sample Input**
# ```
# Use suitable values
# ```
#
# **Expected Output**
# ```
# Display the required details correctly.
# ```

# %%
# Write your code here
class Animal:
    def speak(self):
        print("hello, i am dog.")

class Dog(Animal):
    pass
obj=Dog()
obj.speak()
# Out:
# hello, i am dog.

# %% [markdown]
# ## Question 10
#
# Create a parent class `Vehicle` and child class `Bike`. Add one method in each class and call both methods using the child object.
#
# **Sample Input**
# ```
# Use suitable values
# ```
#
# **Expected Output**
# ```
# Display the required details correctly.
# ```

# %%
# Write your code here
class Vehicle:
    def fuel_type(self):
        print("hello i use diesel and petrol.")


class Bike(Vehicle):
    def fuel(self):
        print("i only use petrol")

obj=Bike()
obj.fuel_type()
obj.fuel()
# Out:
# hello i use diesel and petrol.
# i only use petrol
