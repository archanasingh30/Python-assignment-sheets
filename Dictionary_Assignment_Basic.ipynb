# %% [markdown]
# # Dictionary Assignment (Basic Level)
#
# Questions 1 to 14 with Input/Output examples.

# %% [markdown]
# ## Question 1: Create a Dictionary
#
# Input:
# Name=Raj, Age=20, City=Bhopal
#
# Output:
# {'Name':'Raj','Age':20,'City':'Bhopal'}

# %%
Name={"Name":"Raj","Age":20,"City":"Bhopal"}
print(Name)
# Out:
# {'Name': 'Raj', 'Age': 20, 'City': 'Bhopal'}

# %% [markdown]
# ## Question 2: Print Name
#
# Input:
# {'Name':'Raj','Age':20}
#
# Output:
# Raj

# %%
info={"name":"Raj","age":20}
info["name"]
# Out:
# 'Raj'

# %% [markdown]
# ## Question 3: Print Age
#
# Input:
# {'Name':'Raj','Age':20}
#
# Output:
# 20

# %%
info={"name":"Raj","Age":20}
info["Age"]
# Out:
# 20

# %% [markdown]
# ## Question 4: User Input Dictionary
#
# Input:
# Rahul
# 22
#
# Output:
# {'Name':'Rahul','Age':22}

# %%
Name=input("enter your name")
Age=int(input("Enter your age"))
d={}
d['Name']=Name
d['Age']=Age

print(d)
# Out:
# {'Name': 'Rahul', 'Age': 22}

# %% [markdown]
# ## Question 5: Add New Key
#
# Input:
# {'Name':'Raj','Age':20}
# Add Course='Python'
#
# Output:
# {'Name':'Raj','Age':20,'Course':'Python'}

# %%
info={"Name":"Raj","Age":20}
info['course']="pyhton"
print(info)
# Out:
# {'Name': 'Raj', 'Age': 20, 'course': 'pyhton'}

# %% [markdown]
# ## Question 6: Update Value
#
# Input:
# {'Name':'Raj','Age':20}
#
# Output:
# {'Name':'Raj','Age':25}

# %%
info={"Name":"Raj","Age":20}
info["Age"]=25
print(info)
# Out:
# {'Name': 'Raj', 'Age': 25}

# %% [markdown]
# ## Question 7: Count Total Keys
#
# Input:
# {'Name':'Raj','Age':20,'City':'Bhopal'}
#
# Output:
# 3

# %%
info={"Name":"Raj","Age":20,"city":"Bhopal"}
key_count=len(info.keys())

    
print(key_count)
# Out:
# 3

# %% [markdown]
# ## Question 8: Print All Keys
#
# Input:
# {'Name':'Raj','Age':20,'City':'Bhopal'}
#
# Output:
# dict_keys(['Name','Age','City'])

# %%
info={"name":"raj","age":20,"city":"bhopal"}
print(info.keys())
# Out:
# dict_keys(['name', 'age', 'city'])

# %% [markdown]
# ## Question 9: Print All Values
#
# Input:
# {'Name':'Raj','Age':20,'City':'Bhopal'}
#
# Output:
# dict_values(['Raj',20,'Bhopal'])

# %%
info={"name":"raj","age":20,"city":"bhopal"}
print(info.values())
# Out:
# dict_values(['raj', 20, 'bhopal'])

# %% [markdown]
# ## Question 10: Print All Key-Value Pairs
#
# Input:
# {'Name':'Raj','Age':20,'City':'Bhopal'}
#
# Output:
# Name : Raj
# Age : 20
# City : Bhopal

# %%
info={"name":"raj","age":20,"city":"bhopal"}
print(info.items())
# Out:
# dict_items([('name', 'raj'), ('age', 20), ('city', 'bhopal')])

# %% [markdown]
# ## Question 11: Check Key Exists
#
# Input:
# Age
#
# Output:
# Key Found

# %%
key=input("enter your key you want to find:")
info={"name":"raaj","Age":20}

if key in info:
    print("key found")
else:
    print("key does not exist")
# Out:
# key does not exist

# %% [markdown]
# ## Question 12: Delete a Key
#
# Input:
# {'Name':'Raj','Age':20,'City':'Bhopal'}
# Delete City
#
# Output:
# {'Name':'Raj','Age':20}

# %%
info={"name":"raj","age":20,"city":"bhopal"}
info.pop("city")
print(info)
# Out:
# {'name': 'raj', 'age': 20}

# %% [markdown]
# ## Question 13: Find Dictionary Size
#
# Input:
# {'Name':'Raj','Age':20,'City':'Bhopal'}
#
# Output:
# 3

# %%
info={"name":"raj","age":20,"city":"bhopal"}
count=len(info)
print(count)
# Out:
# 3

# %% [markdown]
# ## Question 14: Merge Two Dictionaries
#
# Input:
# d1={'a':1,'b':2}
# d2={'c':3,'d':4}
#
# Output:
# {'a':1,'b':2,'c':3,'d':4}

# %%
d1={'a':1,'b':2}
d2={"c":3,'d':4}
d1.update(d2)
print(d1)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
